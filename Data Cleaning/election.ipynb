# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import ssl

# %%
url1 = "https://www.nbcnews.com/politics/2020-elections/president-results/"

url = "https://en.wikipedia.org/wiki/2020_United_States_presidential_election#Results"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
ssl._create_default_https_context = ssl._create_unverified_context

scraper = pd.read_html(url)
for idx, table in enumerate(scraper):
    print("****************************************************************")
    print(idx)
    print(table)
# Out:
# ****************************************************************
# 0
#                                                     0  \
# 0                                                 NaN
# 1                   ← 2016 November 3, 2020[a] 2024 →
# 2                                              ← 2016
# 3   538 members of the Electoral College 270 elect...
# 4                                       Opinion polls
# 5                                             Turnout
# 6   Nominee Joe Biden Donald Trump Party Democrati...
# 7                                                 NaN
# 8                                             Nominee
# 9                                               Party
# 10                                         Home state
# 11                                       Running mate
# 12                                     Electoral vote
# 13                                     States carried
# 14                                       Popular vote
# ...

# %%
results_df=pd.DataFrame(scraper[21])
# Export the election_Data into a csv
results_df.to_csv("outputs/election.csv", index_label="False")
