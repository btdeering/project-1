# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from pathlib import Path
from us import states

# %%
death_date = Path("C:/Users/cmfjr/PROJECT1/project-1/covid_deaths_usafacts.csv")
death_date_df = pd.read_csv(death_date)

death_date_df_2020 = death_date_df.loc[:, ['State', '3/19/2020', '6/20/2020', '9/22/2020', '12/21/2020', '3/19/2021', '6/20/2021', '9/22/2021', '12/21/2021']]

#death_date_df_2020 = death_date_df.loc[:, 'State':'12/31/2020']
death_date_df_2020 = death_date_df_2020.groupby('State').sum()
# death_seasons_2020_df = death_date_df_2020.loc[:, 'State' : str(season_columns)]

death_date_df_2020
# Out:
#        3/19/2020  6/20/2020  9/22/2020  12/21/2020  3/19/2021  6/20/2021
# State
# AK             0         12         51         225        317        366  \
# AL             0        838       2446        4389      10429      11306
# AR             0        223       1206        3295       5587       5874
# AZ             0       1337       5492        7971      16692      17822
# CA            24       6023      16261       26900      60722      63116
# CO             2       1639       2025        4339       6076       6733
# CT             3       4251       4496        5676       7833       8270
# DC             0        531        621         742       1047       1141
# DE             0        434        628         869       1522       1679
# FL             8       3144      13414       20671      32668      37555
# GA            10       2632       6669        9452      16115      21318
# HI             0         17        120         269        451        510
# ...
