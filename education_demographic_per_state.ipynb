# %%
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("C:/Users/Marquis Sills/Desktop/DataBootCamp/project_1/demographics_per_state.csv")
df.head()
# Out:
#         state  White alone  White alone High school graduate or higher  \
# 0     Alabama      2353878                                     2115460
# 1      Alaska       314524                                      302619
# 2     Arizona      3171578                                     2985734
# 3    Arkansas      1502180                                     1369911
# 4  California     11574198                                    10855296
#
#    White alone Bachelor's degree or higher  Black alone  \
# 0                                   712934       846228
# 1                                   121059        14708
# 2                                  1191246       208771
# 3                                   411447       276968
# 4                                  5161935      1505960
#
#    Black alone High school graduate or higher  \
# 0                                      719012
# 1                                       14092
# 2                                      194235
# ...

# %%
# Plot out demographics
x_values = df['White alone %']
y_values = df['covid/pop']
plt.scatter(x_values,y_values)

plt.title("Whites vs Covid Deaths (2020)")
plt.xlabel('Percent Whites Only')
plt.ylabel('Covid Death Rates')

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,3))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.20,0.0006),fontsize=15,color="red")

rvalue_rounded = round(rvalue, 3)
plt.annotate(f"r: {rvalue_rounded}",(0.2,0.0004),fontsize=15, color = "black")
print(f"The correlation is: {rvalue_rounded}")

plt.show()
# Out:
# The correlation is: -0.097

# %%
# Plot out demographics
x_values = df['Black alone %']
y_values = df['covid/pop']
plt.scatter(x_values,y_values)

plt.title("Blacks vs Covid Deaths (2020)")
plt.xlabel('Percent Blacks Only')
plt.ylabel('Covid Death Rates')

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.10,0.0006),fontsize=15,color="red")

rvalue_rounded = round(rvalue, 3)
plt.annotate(f"r: {rvalue_rounded}",(0.1,0.0004),fontsize=15, color = "black")
print(f"The correlation is: {rvalue_rounded}")
plt.show()
# Out:
# The correlation is: 0.317

# %%
# Plot out demographics
x_values = df['Asian alone %']
y_values = df['covid/pop']
plt.scatter(x_values,y_values)

plt.title("Asians vs Covid Deaths (2020)")
plt.xlabel('Percent Asian Only')
plt.ylabel('Covid Death Rates')

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.10,0.0006),fontsize=15,color="red")

rvalue_rounded = round(rvalue, 3)
plt.annotate(f"r: {rvalue_rounded}",(0.1,0.0004),fontsize=15, color = "black")
print(f"The correlation is: {rvalue_rounded}")
plt.show()
# Out:
# The correlation is: -0.244

# %%
# Plot out demographics
x_values = df['Hispanic or Latino Origin %']
y_values = df['covid/pop']
plt.scatter(x_values,y_values)

plt.title("Hispanics vs Covid Deaths (2020)")
plt.xlabel('Percent Hispanice Only')
plt.ylabel('Covid Death Rates')

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.10,0.0006),fontsize=15,color="red")

rvalue_rounded = round(rvalue, 3)
plt.annotate(f"r: {rvalue_rounded}",(0.1,0.0004),fontsize=15, color = "black")
print(f"The correlation is: {rvalue_rounded}")
plt.show()
# Out:
# The correlation is: 0.132

# %%
# Plot out demographics
x_values = df['White alone\xa0Bachelor\'s degree or higher %']
y_values = df['covid/pop']
plt.scatter(x_values,y_values)

plt.title("Whites with Bachelors or Higher vs Covid Deaths (2020)")
plt.xlabel('Percent White with Bachelors or Higher')
plt.ylabel('Covid Death Rates')

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.10,0.0006),fontsize=15,color="red")

rvalue_rounded = round(rvalue, 3)
plt.annotate(f"r: {rvalue_rounded}",(0.1,0.0004),fontsize=15, color = "black")
print(f"The correlation is: {rvalue_rounded}")
plt.show()
# Out:
# The correlation is: -0.163

# %%
# Plot out demographics
x_values = df['Black alone\xa0Bachelor\'s degree or higher %']
y_values = df['covid/pop']
plt.scatter(x_values,y_values)

plt.title("Blacks with Bachelors or Higher vs Covid Deaths (2020)")
plt.xlabel('Percent Black with Bachelors or Higher')
plt.ylabel('Covid Death Rates')

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.03,0.0006),fontsize=15,color="red")

rvalue_rounded = round(rvalue, 3)
plt.annotate(f"r: {rvalue_rounded}",(0.03,0.0004),fontsize=15, color = "black")
print(f"The correlation is: {rvalue_rounded}")
plt.show()
# Out:
# The correlation is: 0.25

# %%
# Plot out demographics
x_values = df['Hispanic or Latino Origin\xa0Bachelor\'s degree or higher %']
y_values = df['covid/pop']
plt.scatter(x_values,y_values)

plt.title("Hispanics with Bachelors or Higher vs Covid Deaths (2020)")
plt.xlabel('Percent Hispanic with Bachelors or Higher')
plt.ylabel('Covid Death Rates')

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.02,0.0006),fontsize=15,color="red")

rvalue_rounded = round(rvalue, 3)
plt.annotate(f"r: {rvalue_rounded}",(0.02,0.0004),fontsize=15, color = "black")
print(f"The correlation is: {rvalue_rounded}")
plt.show()
# Out:
# The correlation is: 0.108

# %%
# Plot out demographics
x_values = df['Asian\xa0Bachelor\'s degree or higher %']
y_values = df['covid/pop']
plt.scatter(x_values,y_values)

plt.title("Asians with Bachelors or Higher vs Covid Deaths (2020)")
plt.xlabel('Percent Asian with Bachelors or Higher')
plt.ylabel('Covid Death Rates')

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0.02,0.0006),fontsize=15,color="red")

rvalue_rounded = round(rvalue, 3)
plt.annotate(f"r: {rvalue_rounded}",(0.02,0.0004),fontsize=15, color = "black")
print(f"The correlation is: {rvalue_rounded}")
plt.show()
# Out:
# The correlation is: -0.162
